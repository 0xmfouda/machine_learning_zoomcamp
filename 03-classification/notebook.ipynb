# %% [markdown]
# # 1. Data Preparation

# %% [markdown]
# #### Download the `csv` file

# %%
import pandas as pd

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-03-churn-prediction/WA_Fn-UseC_-Telco-Customer-Churn.csv'

# %%
# !wget $data -O data-week-3.csv
# Out:
# --2025-10-27 16:31:25--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-03-churn-prediction/WA_Fn-UseC_-Telco-Customer-Churn.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 977501 (955K) [text/plain]
# Saving to: ‘data-week-3.csv’
#
# data-week-3.csv     100%[===================>] 954.59K  --.-KB/s    in 0.05s
#
# 2025-10-27 16:31:25 (19.6 MB/s) - ‘data-week-3.csv’ saved [977501/977501]

# %% [markdown]
# #### Read the file with Pandas

# %%
df = pd.read_csv('data-week-3.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# #### Transpose the dataframe to take a look at the columns

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# ...

# %% [markdown]
# #### Normalize Names

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
# For columns with string values, lowercase the values and replace spaces with underscores.
categorical_names = list(df.dtypes[df.dtypes == 'object'].index)

for c in categorical_names:
  df[c] = df[c].str.lower().str.replace(" ", "_")

# %% [markdown]
# #### Check & Fix Data Types

# %%
df.dtypes
# Out:
# customerid           object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges         object
# churn                object
# dtype: object

# %%
tc = pd.to_numeric(df.totalcharges, errors='coerce')

# %%
tc.isnull().sum()
# Out:
# np.int64(11)

# %%
df[tc.isnull()][['customerid', 'totalcharges']]
# Out:
#       customerid totalcharges
# 488   4472-lvygi            _
# 753   3115-czmzd            _
# 936   5709-lvoeq            _
# 1082  4367-nuyao            _
# 1340  1371-dwpaz            _
# 3331  7644-omvmy            _
# 3826  3213-vvolg            _
# 4380  2520-sgtta            _
# 5218  2923-arzlg            _
# 6670  4075-wkniu            _
# 6754  2775-sefee            _

# %%
df.totalcharges = pd.to_numeric(df.totalcharges, errors='coerce')
df.totalcharges = df.totalcharges.fillna(0)

# %%
df[tc.isnull()][['customerid', 'totalcharges']]
# Out:
#       customerid  totalcharges
# 488   4472-lvygi           0.0
# 753   3115-czmzd           0.0
# 936   5709-lvoeq           0.0
# 1082  4367-nuyao           0.0
# 1340  1371-dwpaz           0.0
# 3331  7644-omvmy           0.0
# 3826  3213-vvolg           0.0
# 4380  2520-sgtta           0.0
# 5218  2923-arzlg           0.0
# 6670  4075-wkniu           0.0
# 6754  2775-sefee           0.0

# %% [markdown]
# #### Convert `Churn` from "Yes/No" to `1/0`

# %%
df.churn.head()
# Out:
# 0     no
# 1     no
# 2    yes
# 3     no
# 4    yes
# Name: churn, dtype: object

# %%
df.churn = (df.churn == 'yes').astype(int)

# %%
df.churn.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: churn, dtype: int64

# %% [markdown]
# # 2. Validation Framework

# %% [markdown]
# #### Standard data split: train, validation, test (60/20/20 distrbution).

# %%
from sklearn.model_selection import train_test_split

# %%
## Look at the docs
train_test_split?

# %%
# splitting data
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

len(df_train),  len(df_val), len(df_test)
# Out:
# (4225, 1409, 1409)

# %%
df_train
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 3897  8015-ihcgw  female              0     yes        yes      72
# 1980  1960-uycnn    male              0      no         no      10
# 6302  9250-wypll  female              0      no         no       5
# 727   6786-obwqr  female              0     yes        yes       5
# 5104  1328-euzhc  female              0     yes         no      18
# ...          ...     ...            ...     ...        ...     ...
# 3774  1309-xgfsn    male              1     yes        yes      52
# 6108  4819-hjpiw    male              0      no         no      18
# 1530  3703-vavcl    male              0     yes        yes       2
# 3701  3812-lrzir  female              0     yes        yes      27
# 4368  1704-nrwye  female              1      no         no       9
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 3897          yes               yes     fiber_optic                  yes  ...
# ...

# %%
# Reset indices so they’re sequential
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
df_train
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 0     8015-ihcgw  female              0     yes        yes      72
# 1     1960-uycnn    male              0      no         no      10
# 2     9250-wypll  female              0      no         no       5
# 3     6786-obwqr  female              0     yes        yes       5
# 4     1328-euzhc  female              0     yes         no      18
# ...          ...     ...            ...     ...        ...     ...
# 4220  1309-xgfsn    male              1     yes        yes      52
# 4221  4819-hjpiw    male              0      no         no      18
# 4222  3703-vavcl    male              0     yes        yes       2
# 4223  3812-lrzir  female              0     yes        yes      27
# 4224  1704-nrwye  female              1      no         no       9
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 0             yes               yes     fiber_optic                  yes  ...
# ...

# %% [markdown]
# #### Extract target variable into seperate arrays

# %%
y_train = df_train.churn.values
y_val = df_val.churn.values
y_test = df_test.churn.values

# %%
# delete churn columns from dataframes
del df_train['churn']
del df_val['churn']
del df_test['churn']

# %%
df_train.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges'],
#       dtype='object')

# %% [markdown]
# # 3. Exploratory Data Analysis

# %%
# checking missing values
df_full_train.isnull().sum()
# Out:
# customerid          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %%
# examine the distribution of target variable
df_full_train.churn.value_counts()
# Out:
# churn
# 0    4113
# 1    1521
# Name: count, dtype: int64

# %%
# to see this as percentage
df_full_train.churn.value_counts(normalize=True)
# Out:
# churn
# 0    0.730032
# 1    0.269968
# Name: proportion, dtype: float64

# %%
# A quicker way to calculate churn rate
df_full_train.churn.mean()
# Out:
# np.float64(0.26996805111821087)

# %%
global_churn_rate = df_full_train.churn.mean()

# %%
global_churn_rate
# Out:
# np.float64(0.26996805111821087)

# %%
df_full_train.dtypes
# Out:
# customerid           object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges        float64
# churn                 int64
# dtype: object

# %%
# Selecting numerical variables
numerical = ['tenure', 'monthlycharges', 'totalcharges']

df_full_train.columns

# Selecting categorical variables, removed 'customerid', 'churn' and numberical variables
categorical = ['gender', 'seniorcitizen', 'partner', 'dependents', 'phoneservice', 'multiplelines', 'internetservice',
       'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling', 'paymentmethod']

# %%
df_full_train[categorical].nunique()
# Out:
# gender              2
# seniorcitizen       2
# partner             2
# dependents          2
# phoneservice        2
# multiplelines       3
# internetservice     3
# onlinesecurity      3
# onlinebackup        3
# deviceprotection    3
# techsupport         3
# streamingtv         3
# streamingmovies     3
# contract            3
# paperlessbilling    2
# paymentmethod       4
# dtype: int64
